# %%
from google.colab import drive

# %%
 drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My Drive
# Out:
# /content/drive/My Drive

# %%
# !git clone https://github.com/eriklindernoren/PyTorch-YOLOv3
# Out:
# Cloning into 'PyTorch-YOLOv3'...
# remote: Enumerating objects: 724, done.
# remote: Total 724 (delta 0), reused 0 (delta 0), pack-reused 724
# Receiving objects: 100% (724/724), 16.18 MiB | 19.58 MiB/s, done.
# Resolving deltas: 100% (411/411), done.

# %%
# %cd /content/drive/My Drive/PyTorch-YOLOv3
# Out:
# /content/drive/My Drive/PyTorch-YOLOv3

# %%
# !bash create_custom_model.sh 3

# %%
# !pip install terminaltables
# Out:
# ...
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp36-none-any.whl size=15356 sha256=4f20097abf92ca17e1a8cf9aeaa56f1deab8abdc4e08f5ed77160be8fcc51394
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# Successfully built terminaltables
# ...

# %%
import terminaltables

# %%
# !python3 train.py --model_def config/yolov3-custom.cfg --data_config config/custom.data
# Out:
# Traceback (most recent call last):
#   File "train.py", line 3, in <module>
#   File "/content/drive/My Drive/PyTorch-YOLOv3/models.py", line 3, in <module>
#     import torch
#   File "/usr/local/lib/python3.6/dist-packages/torch/__init__.py", line 189, in <module>
#     from torch._C import *
# ImportError: numpy.core.multiarray failed to import

# %%
## epoch 5돌아가고 끝남 ram 문제 어떻게 해결해야 할지 생각해봐야 한다

# %%
# !python3 detect.py --model_def config/yolov3-custom.cfg --data_config config/custom.data
# Out:
# usage: detect.py [-h] [--image_folder IMAGE_FOLDER] [--model_def MODEL_DEF]
#                  [--weights_path WEIGHTS_PATH] [--class_path CLASS_PATH]
#                  [--conf_thres CONF_THRES] [--nms_thres NMS_THRES]
#                  [--batch_size BATCH_SIZE] [--n_cpu N_CPU]
#                  [--img_size IMG_SIZE] [--checkpoint_model CHECKPOINT_MODEL]
# detect.py: error: unrecognized arguments: --data_config config/custom.data

# %%
# !python3 detect.py --image_folder data/custom/images/ --weights_path checkpoints/yolov3_ckpt_83.pth
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.8, image_folder='data/custom/images/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='checkpoints/yolov3_ckpt_83.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.041450
# 	+ Batch 1, Inference Time: 0:00:00.027996
# 	+ Batch 2, Inference Time: 0:00:00.031122
# 	+ Batch 3, Inference Time: 0:00:00.027740
# 	+ Batch 4, Inference Time: 0:00:00.027329
# 	+ Batch 5, Inference Time: 0:00:00.027934
# 	+ Batch 6, Inference Time: 0:00:00.027571
# 	+ Batch 7, Inference Time: 0:00:00.028372
# 	+ Batch 8, Inference Time: 0:00:00.028194
# 	+ Batch 9, Inference Time: 0:00:00.030639
# 	+ Batch 10, Inference Time: 0:00:00.026170
# 	+ Batch 11, Inference Time: 0:00:00.028452
# 	+ Batch 12, Inference Time: 0:00:00.026319
# 	+ Batch 13, Inference Time: 0:00:00.028624
# 	+ Batch 14, Inference Time: 0:00:00.025993
# ...

# %%
# !python3 detect.py --image_folder data/samples/
