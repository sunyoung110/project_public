# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My Drive

# %%
# !git clone https://github.com/eriklindernoren/PyTorch-YOLOv3
# Out:
# Cloning into 'PyTorch-YOLOv3'...
# remote: Enumerating objects: 724, done.
# remote: Total 724 (delta 0), reused 0 (delta 0), pack-reused 724
# Receiving objects: 100% (724/724), 16.18 MiB | 19.58 MiB/s, done.
# Resolving deltas: 100% (411/411), done.

# %%
# %cd /content/drive/My Drive/PyTorch-YOLOv3
# %cd config/
# Out:
# /content/drive/My Drive/PyTorch-YOLOv3
# /content/drive/My Drive/PyTorch-YOLOv3/config

# %%
# !bash create_custom_model.sh 3

# %%
# !pip install terminaltables
# Out:
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.6/dist-packages (3.1.0)

# %%
import terminaltables

# %%
# !python3 train.py --model_def config/yolov3-custom.cfg --data_config config/custom.data
# Out:
# 2020-08-06 13:02:32.733160: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Namespace(batch_size=8, checkpoint_interval=1, compute_map=False, data_config='config/custom.data', epochs=100, evaluation_interval=1, gradient_accumulations=2, img_size=416, model_def='config/yolov3-custom.cfg', multiscale_training=True, n_cpu=8, pretrained_weights=None)
# 2020-08-06 13:02:34.395906: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-08-06 13:02:34.399107: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-08-06 13:02:34.399150: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (3b202e9b1d43): /proc/driver/nvidia/version does not exist
# 2020-08-06 13:02:34.406132: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-08-06 13:02:34.406387: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5225880 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-06 13:02:34.406425: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:192: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   loss_x = self.mse_loss(x[obj_mask], tx[obj_mask])
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:193: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   loss_y = self.mse_loss(y[obj_mask], ty[obj_mask])
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:194: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   loss_w = self.mse_loss(w[obj_mask], tw[obj_mask])
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:195: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   loss_h = self.mse_loss(h[obj_mask], th[obj_mask])
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:196: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   loss_conf_obj = self.bce_loss(pred_conf[obj_mask], tconf[obj_mask])
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:197: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   loss_conf_noobj = self.bce_loss(pred_conf[noobj_mask], tconf[noobj_mask])
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:199: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   loss_cls = self.bce_loss(pred_cls[obj_mask], tcls[obj_mask])
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:203: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   cls_acc = 100 * class_mask[obj_mask].mean()
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:204: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   conf_obj = pred_conf[obj_mask].mean()
# /content/drive/My Drive/PyTorch-YOLOv3/models.py:205: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   conf_noobj = pred_conf[noobj_mask].mean()
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py:127: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:20.)
#   allow_unreachable=True)  # allow_unreachable flag
#
# ---- [Epoch 0/100, Batch 0/1] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 81.535149    | 71.054703    | 73.394295    |
# | x          | 0.095567     | 0.057296     | 0.001715     |
# | y          | 0.210768     | 0.211980     | 0.168975     |
# | w          | 0.502147     | 0.065183     | 0.128608     |
# | h          | 0.138710     | 0.025932     | 1.440807     |
# | conf       | 79.709579    | 69.996254    | 70.850479    |
# | cls        | 0.878383     | 0.698061     | 0.803714     |
# | cls_acc    | 0.00%        | 0.00%        | 0.00%        |
# | recall50   | 0.000000     | 0.000000     | 0.000000     |
# | recall75   | 0.000000     | 0.000000     | 0.000000     |
# | precision  | 0.000000     | 0.000000     | 0.000000     |
# | conf_obj   | 0.469861     | 0.320177     | 0.676891     |
# | conf_noobj | 0.530650     | 0.492627     | 0.503037     |
# +------------+--------------+--------------+--------------+
# Total loss 225.984130859375
# ---- ETA 0:00:00
#
# ---- Evaluating Model ----
# Detecting objects: 100% 1/1 [00:05<00:00,  5.61s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 103.00it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | train      | 0.00000 |
# +-------+------------+---------+
# ---- mAP 0.0
#
# ---- [Epoch 1/100, Batch 0/1] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 82.214920    | 72.075859    | 74.090431    |
# | x          | 0.412271     | 0.232432     | 0.022478     |
# | y          | 0.313755     | 0.547114     | 0.170933     |
# | w          | 0.145801     | 0.728113     | 0.175857     |
# | h          | 1.026066     | 0.165625     | 1.610029     |
# | conf       | 79.387825    | 69.709160    | 71.251320    |
# | cls        | 0.929197     | 0.693416     | 0.859816     |
# | cls_acc    | 0.00%        | 0.00%        | 0.00%        |
# | recall50   | 0.000000     | 0.000000     | 0.000000     |
# | recall75   | 0.000000     | 0.000000     | 0.000000     |
# | precision  | 0.000000     | 0.000000     | 0.000000     |
# | conf_obj   | 0.730591     | 0.487327     | 0.438768     |
# | conf_noobj | 0.530913     | 0.493717     | 0.502864     |
# +------------+--------------+--------------+--------------+
# Total loss 228.38119506835938
# ---- ETA 0:00:00
#
# ---- Evaluating Model ----
# Detecting objects: 100% 1/1 [00:06<00:00,  6.91s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 26.66it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | train      | 0.00000 |
# +-------+------------+---------+
# ---- mAP 0.0
#
# ---- [Epoch 2/100, Batch 0/1] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 119.077957   | 82.364967    | 85.799606    |
# | x          | 0.007179     | 0.302439     | 0.032752     |
# | y          | 0.240036     | 0.065710     | 0.056158     |
# | w          | 29.139771    | 18.272610    | 6.378751     |
# | h          | 25.080704    | 2.539196     | 12.347507    |
# | conf       | 64.304924    | 60.838951    | 66.150841    |
# | cls        | 0.305340     | 0.346064     | 0.833604     |
# | cls_acc    | 100.00%      | 100.00%      | 0.00%        |
# | recall50   | 0.000000     | 0.000000     | 0.000000     |
# | recall75   | 0.000000     | 0.000000     | 0.000000     |
# | precision  | 0.000000     | 0.000000     | 0.000000     |
# | conf_obj   | 0.596514     | 0.850390     | 0.798859     |
# | conf_noobj | 0.445690     | 0.445886     | 0.479956     |
# +------------+--------------+--------------+--------------+
# Total loss 287.2425537109375
# ---- ETA 0:00:00
#
# ---- Evaluating Model ----
# Detecting objects: 100% 1/1 [00:03<00:00,  3.30s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 396.06it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | train      | 0.00000 |
# +-------+------------+---------+
# ---- mAP 0.0
#
# ---- [Epoch 3/100, Batch 0/1] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 14           | 28           | 56           |
# | loss       | 99.834618    | 63.241501    | 73.971268    |
# | x          | 0.022063     | 0.074780     | 0.046936     |
# | y          | 0.188856     | 0.041459     | 0.039924     |
# | w          | 28.028280    | 0.297138     | 3.220124     |
# | h          | 8.313582     | 0.230464     | 3.670717     |
# | conf       | 63.120014    | 61.597294    | 66.242386    |
# | cls        | 0.161827     | 1.000366     | 0.751180     |
# | cls_acc    | 100.00%      | 0.00%        | 0.00%        |
# | recall50   | 0.000000     | 0.000000     | 0.000000     |
# | recall75   | 0.000000     | 0.000000     | 0.000000     |
# | precision  | 0.000000     | 0.000000     | 0.000000     |
# | conf_obj   | 0.864702     | 0.569429     | 0.733299     |
# | conf_noobj | 0.444623     | 0.446982     | 0.480097     |
# +------------+--------------+--------------+--------------+
# Total loss 237.04737854003906
# ---- ETA 0:00:00
#
# ---- Evaluating Model ----
# Detecting objects: 100% 1/1 [00:01<00:00,  1.82s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 2847.46it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | train      | 0.00000 |
# +-------+------------+---------+
# ---- mAP 0.0
#
# ---- [Epoch 4/100, Batch 0/1] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 114.133400   | 59.700798    | 68.968193    |
# | x          | 0.024428     | 0.127681     | 0.000085     |
# | y          | 0.000023     | 0.187663     | 0.171918     |
# | w          | 42.104023    | 1.015472     | 1.873178     |
# | h          | 20.664204    | 1.259709     | 3.921376     |
# | conf       | 50.554607    | 56.271500    | 62.382450    |
# | cls        | 0.786111     | 0.838775     | 0.619183     |
# | cls_acc    | 0.00%        | 0.00%        | 100.00%      |
# | recall50   | 0.000000     | 0.000000     | 0.000000     |
# | recall75   | 0.000000     | 0.000000     | 0.000000     |
# | precision  | 0.000000     | 0.000000     | 0.000000     |
# | conf_obj   | 0.130882     | 0.181314     | 0.526229     |
# | conf_noobj | 0.372561     | 0.415693     | 0.458297     |
# +------------+--------------+--------------+--------------+
# Total loss 242.80239868164062
# ---- ETA 0:00:00
#
# ---- Evaluating Model ----
# Detecting objects: 100% 1/1 [00:02<00:00,  2.27s/it]
# Computing AP: 100% 1/1 [00:00<00:00, 677.48it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | train      | 0.00000 |
# +-------+------------+---------+
# ---- mAP 0.0
#
# ---- [Epoch 5/100, Batch 0/1] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 11           | 22           | 44           |
# | loss       | 134.124023   | 57.235634    | 67.143509    |
# | x          | 0.002543     | 0.130366     | 0.035457     |
# | y          | 0.002657     | 0.062215     | 0.288226     |
# | w          | 61.593216    | 0.984495     | 0.782687     |
# | h          | 23.024614    | 0.332969     | 3.124569     |
# | conf       | 48.907700    | 55.206280    | 62.206387    |
# | cls        | 0.593292     | 0.519309     | 0.706182     |
# | cls_acc    | 100.00%      | 100.00%      | 0.00%        |
# | recall50   | 0.000000     | 0.000000     | 0.000000     |
# | recall75   | 0.000000     | 0.000000     | 0.000000     |
# | precision  | 0.000000     | 0.000000     | 0.000000     |
# | conf_obj   | 0.231290     | 0.251242     | 0.599273     |
# | conf_noobj | 0.365040     | 0.411653     | 0.458048     |
# +------------+--------------+--------------+--------------+
# Total loss 258.503173828125
# ---- ETA 0:00:00
#
# ---- Evaluating Model ----
# Detecting objects:   0% 0/1 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "train.py", line 160, in <module>
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#     batch_size=8,
#   File "/content/drive/My Drive/PyTorch-YOLOv3/test.py", line 48, in evaluate
#     outputs = non_max_suppression(outputs, conf_thres=conf_thres, nms_thres=nms_thres)
#   File "/content/drive/My Drive/PyTorch-YOLOv3/utils/utils.py", line 258, in non_max_suppression
#     detections[0, :4] = (weights * detections[invalid, :4]).sum(0) / weights.sum()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 2041) is killed by signal: Killed.
# Detecting objects:   0% 0/1 [08:47<?, ?it/s]

# %%
## epoch 5돌아가고 끝남 ram 문제 어떻게 해결해야 할지 생각해봐야 한다
